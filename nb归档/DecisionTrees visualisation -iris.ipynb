# %%
import math
import random
import itertools
import numpy as np
import pandas as pd
from tqdm import tqdm

from sklearn.datasets import load_breast_cancer, load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='white')
sns.set_palette("bright")
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import os     
os.environ["PATH"] += '/Users/ness001/data science/plots'

# %% [markdown]
# # Iris Dataset

# %%
iris = load_iris()
X_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
y_iris = iris.target

# %%
iris['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris_dt = DecisionTreeClassifier()
iris_dt.fit(X_iris, y_iris)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
iris_dot_data = StringIO()
print('Features: ', iris.feature_names)
print('Targets: ', iris.target_names)
export_graphviz(iris_dt, out_file=iris_dot_data,
                class_names=iris.target_names,
                filled=True, rounded=True,
                feature_names=iris.feature_names,
                precision=1,
                special_characters=True)
iris_graph = pydotplus.graph_from_dot_data(iris_dot_data.getvalue())  
iris_graph.write_png('/Users/ness001/data science/plots/iris_decision_tree.png')
Image(iris_graph.create_png())
# Out:
# Features:  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Targets:  ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# # Breast Cancer Dataset

# %%
bc = load_breast_cancer()
X_bc = pd.DataFrame(bc.data, columns=bc.feature_names)
y_bc = bc.target

# %%
bc['feature_names']
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
bc_dt = DecisionTreeClassifier()
bc_dt.fit(X_bc, y_bc)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
bc_dot_data = StringIO()
print('Features: ', bc.feature_names)
print('Targets: ', bc.target_names)
export_graphviz(bc_dt, out_file=bc_dot_data,
                class_names=bc.target_names,
                filled=True, rounded=True,
                feature_names=bc.feature_names,
                precision=1,
                special_characters=True)
bc_graph = pydotplus.graph_from_dot_data(bc_dot_data.getvalue())  
bc_graph.write_png('/Users/ness001/data science/plots/bc_decision_tree.png')
Image(bc_graph.create_png())
# Out:
# Features:  ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
# Targets:  ['malignant' 'benign']
