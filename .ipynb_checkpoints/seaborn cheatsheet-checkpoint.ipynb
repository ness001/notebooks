# %% [markdown]
# 2019.4.29 7:10pm

# %%
cd /Users/ness001/ds/code_data/
# Out:
# /Users/ness001/ds/code_data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import seaborn as sns

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %% [markdown]
# ## scatter plot

# %%
sns.jointplot(x='SepalLength',y='PetalLength',data=iris)

# %%
sns.jointplot(x='SepalLength',y='PetalLength',data=iris,kind='reg')

# %%
sns.jointplot(x='SepalLength',y='PetalLength',data=iris,kind='hex')

# %%
sns.jointplot(x='SepalLength',y='PetalLength',data=iris,kind='kde',space=0)

# %% [markdown]
# ## boxplot

# %%
tips=sns.load_dataset('tips')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxplot(x='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=tips)

# %% [markdown]
# ## histogram

# %%
sns.distplot(x='total_bill',data=tips)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-04495b07ca6e> in <module>
# ----> 1 sns.distplot(x='total_bill',data=tips)
#
# TypeError: distplot() got an unexpected keyword argument 'x'

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],rug=True)

# %%
sns.distplot(tips['total_bill'],rug=True,hist=False
            )

# %%
from scipy.stats import norm

# %%
sns.distplot(tips['total_bill'],fit=norm,kde=False)

# %%
sns.distplot(tips['total_bill'],fit=norm,kde=True)

# %%
sns.distplot(tips['total_bill'],fit=norm,kde=True,vertical=True)

# %% [markdown]
# ## countplot

# %%
sns.countplot(x='day',data=tips)

# %%
sns.countplot(x='day',hue='sex',data=tips)

# %%
sns.countplot(y='day',hue='sex',data=tips)

# %% [markdown]
# ## kde plot

# %%
sns.kdeplot(tips['total_bill'])

# %%
sns.kdeplot(tips['total_bill'],shade=True)

# %%
sns.kdeplot(tips['total_bill'],tips['tip'])

# %%
sns.kdeplot(tips['total_bill'],tips['tip'],n_levels=30)

# %% [markdown]
# ## violin plot(boxplot+kde)

# %%
sns.violinplot(x='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',hue='smoker',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',hue='smoker',data=tips,split=True)

# %% [markdown]
# ## pairplots

# %%
sns.set(style='ticks',color_codes=True)

# %%
sns.pairplot(iris,hue='Name')

# %%
sns.pairplot(iris,hue='Name',diag_kind='hist')

# %%
sns.set(style='darkgrid')

# %%
sns.pairplot(iris,diag_kind='kde',kind='reg',markers='*')

# %% [markdown]
# ### custom variables

# %%
sns.pairplot(iris,markers='+',x_vars=['SepalLength', 'SepalWidth'],y_vars=['PetalLength', 'PetalWidth'],kind='reg',hue='Name')

# %%
sns.pairplot(iris,markers='+',vars=['SepalLength', 'SepalWidth'],hue='Name')

# %% [markdown]
# ## regression plot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',data=tips)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',col='smoker',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',row='smoker',col='day',data=tips,height=4)
